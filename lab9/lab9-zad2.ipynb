# %% [markdown]
# # Laboratorium 9 - zadanie 2

# %% [markdown]
# ## Import zależności

# %%
import matplotlib as ml
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
from skimage import measure

from PIL import Image
from PIL import ImageOps    

import numpy as np 
from numpy import fft
from numpy import linalg

import importlib

# %%
import image_tools
importlib.reload(image_tools)
from image_tools import read_img, convert_img

# %%
import fonts_manager
importlib.reload(fonts_manager)
from fonts_manager import FontsManager

# %%
import ocr
importlib.reload(ocr)
from ocr import Ocr

# %% [markdown]
# ## Funkcje pomocnicze

# %%
def show_img(img, cmap='gray', scale=50):
    plt.figure(figsize=(img.shape[0] // scale, img.shape[1] // scale))
    plt.imshow(img, cmap=cmap, interpolation='none')
    plt.show()

# %% [markdown]
# ## Zadanie 2

# %%
ocr = Ocr()

# %%
img_path = 'short.png'
show_img(read_img(img_path, invert=False), scale=7)

# %%
text = ocr.parse_text('short.png', 'roboto_mono')
print(text)
# Out:
# To be or not to be that is the question
# Wmether tis nobIer in the Find to suffer
# The sIings amd arrows of outrageous fortune
